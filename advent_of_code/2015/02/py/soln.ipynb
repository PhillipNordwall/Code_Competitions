# %%
with open("../input") as f: inp = list(map(lambda x: sorted(map(int, x.split("x"))), f.read().split()))

# %%
ins = [sorted([i[0]*i[1], i[0]*i[2], i[1]* i[2]]) for i in inp]
sum(map(lambda x: 3*x[0] + 2*x[1] + 2*x[2], ins))
# Out:
# 1598415

# %%
sum(map(lambda x: 2*x[0] + 2*x[1] + [0]*x[1]*x[2], inp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2cd3dc995b1b> in <module>()
#       1
# ----> 2 sum(map(lambda x: 2*x[0] + 2*x[1] + [x0]*x[1]*x[2], inp))
#
# <ipython-input-35-2cd3dc995b1b> in <lambda>(x)
#       1
# ----> 2 sum(map(lambda x: 2*x[0] + 2*x[1] + [x0]*x[1]*x[2], inp))
#
# NameError: name 'x0' is not defined

# %%
inp
# Out:
# [[4, 21, 23],
#  [19, 22, 29],
#  [4, 11, 11],
#  [5, 8, 10],
#  [16, 18, 24],
#  [11, 22, 25],
#  [2, 13, 20],
#  [14, 15, 24],
#  [2, 14, 22],
#  [3, 7, 30],
#  [22, 25, 30],
#  [9, 9, 29],
#  [26, 29, 29],
#  [3, 14, 16],
#  [1, 10, 26],
#  [2, 29, 30],
#  [10, 25, 30],
#  [10, 20, 26],
#  [1, 2, 18],
#  [5, 18, 25],
#  [3, 21, 24],
#  [2, 5, 7],
#  [11, 21, 22],
#  [8, 8, 11],
#  [2, 16, 18],
#  [3, 8, 13],
#  [1, 16, 19],
#  [12, 16, 19],
#  [1, 15, 21],
#  [4, 9, 29],
#  [8, 10, 27],
#  [2, 7, 27],
#  [2, 20, 23],
#  [5, 11, 24],
#  [2, 8, 27],
#  [10, 10, 28],
#  [10, 11, 24],
#  [2, 12, 19],
#  [5, 10, 27],
#  [1, 14, 25],
#  [5, 14, 30],
#  [12, 15, 26],
#  [20, 22, 23],
#  [1, 5, 12],
#  [9, 9, 26],
#  [5, 23, 25],
#  [16, 19, 28],
#  [17, 17, 23],
#  [2, 20, 27],
#  [13, 18, 27],
#  [7, 16, 18],
#  [7, 22, 29],
#  [6, 17, 28],
#  [9, 17, 22],
#  [5, 6, 10],
#  [2, 12, 14],
#  [5, 6, 25],
#  [9, 10, 26],
#  [6, 19, 21],
#  [4, 19, 27],
#  [14, 16, 23],
#  [17, 21, 29],
# ...
